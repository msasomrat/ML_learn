# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data_science_job.csv')

# %%
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  18679 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  float64
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  training_hours          18392 non-null  float64
#  12  target                  19158 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#         enrollee_id  city_development_index    experience  training_hours  \
# count  19158.000000            18679.000000  19093.000000    18392.000000
# mean   16875.358179                0.828951      9.928036       65.185787
# std     9616.292592                0.123334      6.505268       59.885626
# min        1.000000                0.448000      0.000000        1.000000
# 25%     8554.250000                0.740000      4.000000       23.000000
# 50%    16982.500000                0.903000      9.000000       47.000000
# 75%    25169.750000                0.920000     16.000000       88.000000
# max    33380.000000                0.949000     20.000000      336.000000
#
#              target
# count  19158.000000
# mean       0.249348
# std        0.432647
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.isna().sum()
# Out:
# enrollee_id                  0
# city                         0
# city_development_index     479
# gender                    4508
# relevent_experience          0
# enrolled_university        386
# education_level            460
# major_discipline          2813
# experience                  65
# company_size              5938
# company_type              6140
# training_hours             766
# target                       0
# dtype: int64

# %%
df.isna().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
df.isna().mean()
# Out:
# enrollee_id               0.000000
# city                      0.000000
# city_development_index    0.025003
# gender                    0.235306
# relevent_experience       0.000000
# enrolled_university       0.020148
# education_level           0.024011
# major_discipline          0.146832
# experience                0.003393
# company_size              0.309949
# company_type              0.320493
# training_hours            0.039983
# target                    0.000000
# dtype: float64

# %%
column = [var for var in df.columns if df[var].isnull().mean() < 0.05 and df[var].isnull().mean() > 0]

# %%
column
# Out:
# ['city_development_index',
#  'enrolled_university',
#  'education_level',
#  'experience',
#  'training_hours']

# %%
df[column].sample(5)
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 3530                    0.939       no_enrollment             Phd        15.0
# 3655                    0.939    Full time course        Graduate         9.0
# 154                     0.910       no_enrollment         Masters        20.0
# 2616                    0.920       no_enrollment         Masters        15.0
# 15197                   0.920       no_enrollment     High School         3.0
#
#        training_hours
# 3530             40.0
# 3655              NaN
# 154              55.0
# 2616             21.0
# 15197            44.0

# %%
len(df[column].dropna())/ len(df)
# Out:
# 0.8968577095730244

# %%
df2 = df[column].dropna()

# %%
df.shape
# Out:
# (19158, 13)

# %%
df2.shape
# Out:
# (17182, 5)

# %%
df2
# Out:
#        city_development_index enrolled_university education_level  experience  \
# 0                       0.920       no_enrollment        Graduate        20.0
# 1                       0.776       no_enrollment        Graduate        15.0
# 2                       0.624    Full time course        Graduate         5.0
# 4                       0.767       no_enrollment         Masters        20.0
# 5                       0.764    Part time course        Graduate        11.0
# ...                       ...                 ...             ...         ...
# 19153                   0.878       no_enrollment        Graduate        14.0
# 19154                   0.920       no_enrollment        Graduate        14.0
# 19155                   0.920       no_enrollment        Graduate        20.0
# 19156                   0.802       no_enrollment     High School         0.0
# 19157                   0.855       no_enrollment  Primary School         2.0
#
#        training_hours
# ...

# %%
df2.hist(bins=50, density = True, figsize=(12,12))
plt.show()

# %%
df.hist(bins=50, density = True, figsize=(12,12))
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['training_hours'].hist(bins=50, ax=ax, density=True, color='red')


df2['training_hours'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')


df2['city_development_index'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['training_hours'].plot.density( color='red')


df2['training_hours'].plot.density( color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['city_development_index'].hist(bins=50, ax=ax, density=True, color='red')


df2['city_development_index'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['city_development_index'].plot.density( color='red')


df2['city_development_index'].plot.density( color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['experience'].hist(bins=50, ax=ax, density=True, color='red')


df2['experience'].hist(bins=50, ax=ax, color='green', density=True, alpha=0.8)
# Out:
# <Axes: >

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)


df['experience'].plot.density( color='red')


df2['experience'].plot.density( color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
df['education_level'].value_counts()
# Out:
# education_level
# Graduate          11598
# Masters            4361
# High School        2017
# Phd                 414
# Primary School      308
# Name: count, dtype: int64

# %%
temp = pd.concat([
            df['enrolled_university'].value_counts() / len(df),
            df2['enrolled_university'].value_counts() / len(df2)
        ],
        axis=1)

# %%
temp.columns = ['original', 'cca']

# %%
temp
# Out:
#                      original       cca
# enrolled_university
# no_enrollment        0.721213  0.735188
# Full time course     0.196106  0.200733
# Part time course     0.062533  0.064079

# %%
temp = pd.concat([
            df['education_level'].value_counts() / len(df),
            df2['education_level'].value_counts() / len(df2)
        ],
        axis=1)

# %%
temp.columns = ['original', 'cca']

# %%
temp
# Out:
#                  original       cca
# education_level
# Graduate         0.605387  0.619835
# Masters          0.227633  0.234082
# High School      0.105282  0.107380
# Phd              0.021610  0.022116
# Primary School   0.016077  0.016587
