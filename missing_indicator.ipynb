# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sn
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = pd.read_csv('titanic.csv', usecols=['Age', 'Fare', 'Survived'])

# %%
df
# Out:
#      Survived   Age     Fare
# 0           0  22.0   7.2500
# 1           1  38.0  71.2833
# 2           1  26.0   7.9250
# 3           1  35.0  53.1000
# 4           0  35.0   8.0500
# ..        ...   ...      ...
# 886         0  27.0  13.0000
# 887         1  19.0  30.0000
# 888         0   NaN  23.4500
# 889         1  26.0  30.0000
# 890         0  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Age       714 non-null    float64
#  2   Fare      891 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 21.0 KB

# %%
df.describe()
# Out:
#          Survived         Age        Fare
# count  891.000000  714.000000  891.000000
# mean     0.383838   29.699118   32.204208
# std      0.486592   14.526497   49.693429
# min      0.000000    0.420000    0.000000
# 25%      0.000000   20.125000    7.910400
# 50%      0.000000   28.000000   14.454200
# 75%      1.000000   38.000000   31.000000
# max      1.000000   80.000000  512.329200

# %%
df.isnull().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
df.isnull().mean()
# Out:
# Survived    0.000000
# Age         0.198653
# Fare        0.000000
# dtype: float64

# %%
x = df.drop(columns=['Survived'])
y = df['Survived']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
x_test
# Out:
#       Age     Fare
# 707  42.0  26.2875
# 37   21.0   8.0500
# 615  24.0  65.0000
# 169  28.0  56.4958
# 68   17.0   7.9250
# ..    ...      ...
# 89   24.0   8.0500
# 80   22.0   9.0000
# 846   NaN  69.5500
# 870  26.0   7.8958
# 251  29.0  10.4625
#
# [179 rows x 2 columns]

# %%
x_train.shape
# Out:
# (712, 2)

# %%
x_test.shape
# Out:
# (179, 2)

# %%
x_train['Age_imputed'] = x_train['Age']
x_test['Age_imputed'] = x_test['Age']

# %%
x_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125          NaN
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792          NaN
# 168   NaN   25.9250          NaN
#
# [712 rows x 3 columns]

# %%
x_test
# Out:
#       Age     Fare  Age_imputed
# 707  42.0  26.2875         42.0
# 37   21.0   8.0500         21.0
# 615  24.0  65.0000         24.0
# 169  28.0  56.4958         28.0
# 68   17.0   7.9250         17.0
# ..    ...      ...          ...
# 89   24.0   8.0500         24.0
# 80   22.0   9.0000         22.0
# 846   NaN  69.5500          NaN
# 870  26.0   7.8958         26.0
# 251  29.0  10.4625         29.0
#
# [179 rows x 3 columns]

# %%
x_test.isna().sum()
# Out:
# Age            29
# Fare            0
# Age_imputed    29
# dtype: int64

# %%
x_train['Age_imputed'][x_train['Age_imputed'].isnull()]
# Out:
# 77    NaN
# 868   NaN
# 334   NaN
# 295   NaN
# 792   NaN
#        ..
# 674   NaN
# 466   NaN
# 584   NaN
# 527   NaN
# 168   NaN
# Name: Age_imputed, Length: 148, dtype: float64

# %%
x_test['Age_imputed'][x_test['Age_imputed'].isnull()]
# Out:
# 692   NaN
# 643   NaN
# 65    NaN
# 128   NaN
# 185   NaN
# 335   NaN
# 557   NaN
# 158   NaN
# 563   NaN
# 250   NaN
# 109   NaN
# 602   NaN
# 384   NaN
# 468   NaN
# 656   NaN
# 522   NaN
# 431   NaN
# 740   NaN
# 732   NaN
# 101   NaN
# 481   NaN
# 739   NaN
# 304   NaN
# 711   NaN
# 198   NaN
# 444   NaN
# 107   NaN
# 639   NaN
# 846   NaN
# Name: Age_imputed, dtype: float64

# %%
x_train['Age'].dropna().sample(x_train['Age'].isnull().sum()).values
# Out:
# array([36.  , 23.  , 21.  , 21.  , 17.  , 32.  , 48.  , 45.5 , 40.  ,
#        27.  , 15.  , 32.  ,  9.  , 30.  , 44.  , 54.  , 39.  ,  4.  ,
#        47.  , 19.  , 50.  , 65.  , 34.  , 24.  , 44.  , 24.  , 24.  ,
#        34.  , 39.  , 19.  , 40.  , 37.  , 30.  , 65.  , 21.  , 47.  ,
#        50.  , 34.5 , 36.  , 19.  , 20.  , 14.  , 28.5 , 30.  , 49.  ,
#        21.  , 17.  , 38.  , 25.  , 29.  , 22.  , 24.  , 28.  , 18.  ,
#         4.  , 26.  , 14.  , 32.  , 33.  , 37.  , 18.  , 51.  , 31.  ,
#         0.83, 27.  , 28.5 , 19.  , 28.  , 22.  , 45.  , 23.  , 25.  ,
#        26.  , 10.  , 56.  , 26.  , 35.  ,  7.  , 28.  , 18.  , 16.  ,
#        20.  , 18.  , 28.  , 17.  , 32.  , 15.  , 42.  , 27.  , 30.  ,
#        33.  , 16.  ,  0.67, 26.  , 26.  ,  2.  , 43.  , 21.  , 48.  ,
#        61.  , 13.  , 58.  , 34.  , 27.  ,  3.  ,  9.  , 16.  , 47.  ,
#        20.  , 33.  , 17.  , 58.  , 25.  , 21.  , 16.  , 30.  , 34.  ,
# ...

# %%
x_train['Age'].isnull().sum()
# Out:
# 148

# %%
x_train.loc[x_train['Age_imputed'].isnull(), 'Age_imputed'] = x_train['Age'].dropna().sample(
    n=x_train['Age_imputed'].isnull().sum(), random_state=0, replace=True).values


x_test.loc[x_test['Age_imputed'].isnull(), 'Age_imputed'] = x_train['Age'].dropna().sample(
    n=x_test['Age_imputed'].isnull().sum(), random_state=0, replace=True).values

# %%
x_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         11.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         44.0
# 168   NaN   25.9250         30.0
#
# [712 rows x 3 columns]

# %%
sn.kdeplot(x_train['Age'], label='Original', color='blue')


sn.kdeplot(x_train['Age_imputed'], label='Imputed', color='red')


plt.legend()


plt.show()

# %%
sn.histplot(x_train['Age'], label='Original', color='blue', kde=True, stat="density", bins=30, alpha=0.3)


sn.histplot(x_train['Age_imputed'], label='Imputed', color='red', kde=True, stat="density", bins=30, alpha=0.3)

plt.legend()
plt.show()

# %%
sn.histplot(x_train['Age'].dropna(), label='Original', color='blue', stat="density", bins=30, alpha=0.3)


sn.histplot(x_train['Age_imputed'].dropna(), label='Imputed', color='red', stat="density", bins=30, alpha=0.3)
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sn.histplot(x_train['Age'].dropna(), label='Original', color='blue', stat="density", bins=30, alpha=0.3)

sn.histplot(x_train['Age_imputed'].dropna(), label='Imputed', color='red', stat="density", bins=30, alpha=0.3)


sn.kdeplot(x_train['Age'].dropna(), color='blue')


sn.kdeplot(x_train['Age_imputed'].dropna(), color='red')


plt.legend()


plt.show()

# %%
print('Original variable variance: ', x_train['Age'].var())
print('Variance after random imputation: ', x_train['Age_imputed'].var())
# Out:
# Original variable variance:  204.34951339046142
# Variance after random imputation:  204.79019036469444

# %%
x_train[['Fare', 'Age', 'Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    62.235781
# Age            71.512440  204.349513   204.349513
# Age_imputed    62.235781  204.349513   204.790190

# %%
x_train[['Fare', 'Age', 'Age_imputed']].corr()
# Out:
#                  Fare       Age  Age_imputed
# Fare         1.000000  0.095814     0.089366
# Age          0.095814  1.000000     1.000000
# Age_imputed  0.089366  1.000000     1.000000

# %%
x_train[['Age','Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
observation = x_train.iloc[0] 


sampled_value = x_train['Age'].dropna().sample(1, random_state=int(observation['Fare']))

# %%
sampled_value
# Out:
# 399    28.0
# Name: Age, dtype: float64

# %%
sampled_value = x_train['Age'].dropna().sample(x_train['Age'].isnull().sum(), random_state=int(observation['Fare']))

# %%
sampled_value
# Out:
# 399    28.0
# 867    31.0
# 230    35.0
# 416    34.0
# 392    28.0
#        ...
# 222    51.0
# 532    17.0
# 682    20.0
# 797    31.0
# 811    39.0
# Name: Age, Length: 148, dtype: float64

# %%
df2 = pd.read_csv('house-train.csv')

# %%
df2
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df2 = pd.read_csv('house-train.csv',usecols=['GarageQual','FireplaceQu', 'SalePrice'])

# %%
df2
# Out:
#      FireplaceQu GarageQual  SalePrice
# 0            NaN         TA     208500
# 1             TA         TA     181500
# 2             TA         TA     223500
# 3             Gd         TA     140000
# 4             TA         TA     250000
# ...          ...        ...        ...
# 1455          TA         TA     175000
# 1456          TA         TA     210000
# 1457          Gd         TA     266500
# 1458         NaN         TA     142125
# 1459         NaN         TA     147500
#
# [1460 rows x 3 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   FireplaceQu  770 non-null    object
#  1   GarageQual   1379 non-null   object
#  2   SalePrice    1460 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 34.3+ KB

# %%
df2.describe()
# Out:
#            SalePrice
# count    1460.000000
# mean   180921.195890
# std     79442.502883
# min     34900.000000
# 25%    129975.000000
# 50%    163000.000000
# 75%    214000.000000
# max    755000.000000

# %%
df2.isnull().sum()
# Out:
# FireplaceQu    690
# GarageQual      81
# SalePrice        0
# dtype: int64

# %%
df2.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
x = df2
y = df2['SalePrice']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=2)

# %%
x_train['GarageQual_imputed'] = x_train['GarageQual']
x_test['GarageQual_imputed'] = x_test['GarageQual']

# %%
x_train
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imputed
# 455           TA         TA     175500                 TA
# 863          NaN         TA     132500                 TA
# 504           Fa         TA     147000                 TA
# 1413          Gd         TA     257000                 TA
# 1389          Gd         TA     131000                 TA
# ...          ...        ...        ...                ...
# 466           Po         TA     167000                 TA
# 299           Gd         TA     158500                 TA
# 493           Fa         TA     155000                 TA
# 527           Gd         TA     446261                 TA
# 1192         NaN         TA     125000                 TA
#
# [1168 rows x 4 columns]

# %%
x_test
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imputed
# 503           TA         TA     289000                 TA
# 101           TA         TA     178000                 TA
# 608           Gd         TA     359100                 TA
# 1089          Gd         TA     197000                 TA
# 819           Gd         TA     224000                 TA
# ...          ...        ...        ...                ...
# 816           Gd         TA     137000                 TA
# 1273          Gd         TA     177000                 TA
# 285          NaN         TA     164700                 TA
# 194          NaN         TA     127000                 TA
# 318           TA         TA     260000                 TA
#
# [292 rows x 4 columns]

# %%
x_train['FireplaceQu_imputed'] = x_train['FireplaceQu']
x_test['FireplaceQu_imputed'] = x_test['FireplaceQu']

# %%
x_train
# Out:
#      FireplaceQu GarageQual  SalePrice GarageQual_imputed FireplaceQu_imputed
# 455           TA         TA     175500                 TA                  TA
# 863          NaN         TA     132500                 TA                 NaN
# 504           Fa         TA     147000                 TA                  Fa
# 1413          Gd         TA     257000                 TA                  Gd
# 1389          Gd         TA     131000                 TA                  Gd
# ...          ...        ...        ...                ...                 ...
# 466           Po         TA     167000                 TA                  Po
# 299           Gd         TA     158500                 TA                  Gd
# 493           Fa         TA     155000                 TA                  Fa
# 527           Gd         TA     446261                 TA                  Gd
# 1192         NaN         TA     125000                 TA                 NaN
#
# [1168 rows x 5 columns]

# %%
x_train.loc[x_train['GarageQual_imputed'].isnull(), 'GarageQual_imputed'] = (
    x_train['GarageQual'].dropna().sample(
        n=x_train['GarageQual_imputed'].isnull().sum(), 
        replace=True
    ).values
)


x_test.loc[x_test['GarageQual_imputed'].isnull(), 'GarageQual_imputed'] = (
    x_train['GarageQual'].dropna().sample(
        n=x_test['GarageQual_imputed'].isnull().sum(), 
        replace=True
    ).values
)

# %%
x_train.loc[x_train['FireplaceQu_imputed'].isnull(), 'FireplaceQu_imputed'] = (
    x_train['FireplaceQu'].dropna().sample(
        n=x_train['FireplaceQu_imputed'].isnull().sum(), 
        replace=True
    ).values
)


x_test.loc[x_test['FireplaceQu_imputed'].isnull(), 'FireplaceQu_imputed'] = (
    x_train['FireplaceQu'].dropna().sample(
        n=x_test['FireplaceQu_imputed'].isnull().sum(), 
        replace=True
    ).values
)

# %%
temp = pd.concat(
        [
            x_train['GarageQual'].value_counts() / len(x_train['GarageQual'].dropna()),
            x_train['GarageQual_imputed'].value_counts() / len(x_train)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

# %%
temp
# Out:
#     original   imputed
# TA  0.951043  0.950342
# Fa  0.037171  0.038527
# Gd  0.009973  0.009418
# Po  0.000907  0.000856
# Ex  0.000907  0.000856

# %%
temp = pd.concat(
        [
            x_train['FireplaceQu'].value_counts() / len(x_train['FireplaceQu'].dropna()),
            x_train['FireplaceQu_imputed'].value_counts() / len(df2)
        ],
        axis=1)

temp.columns = ['original', 'imputed']

temp
# Out:
#     original   imputed
# Gd  0.494272  0.402740
# TA  0.412439  0.321918
# Fa  0.040917  0.026712
# Po  0.027823  0.023288
# Ex  0.024550  0.025342

# %%
for category in x_train['FireplaceQu'].dropna().unique():
    sn.distplot(x_train[x_train['FireplaceQu'] == category]['SalePrice'],hist=False,label=category)
plt.show()
# Out:
# C:\Users\shoab\AppData\Local\Temp\ipykernel_3216\3515540282.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(x_train[x_train['FireplaceQu'] == category]['SalePrice'],hist=False,label=category)
# C:\Users\shoab\AppData\Local\Temp\ipykernel_3216\3515540282.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for category in x_train['FireplaceQu'].dropna().unique():
    sn.kdeplot(x_train[x_train['FireplaceQu'] == category]['SalePrice'], label=category)

plt.legend()
plt.show()

# %%
for category in x_train['FireplaceQu_imputed'].dropna().unique():
    sn.kdeplot(x_train[x_train['FireplaceQu_imputed'] == category]['SalePrice'], label=category)

plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))


for category in x_train['FireplaceQu'].dropna().unique():
    sn.kdeplot(x_train[x_train['FireplaceQu'] == category]['SalePrice'], 
                label=f'Original - {category}', ax=ax)

# Plot KDEs for imputed categories
for category in x_train['FireplaceQu_imputed'].dropna().unique():
    sn.kdeplot(x_train[x_train['FireplaceQu_imputed'] == category]['SalePrice'], 
                label=f'Imputed - {category}', ax=ax)


plt.legend()
plt.show()
