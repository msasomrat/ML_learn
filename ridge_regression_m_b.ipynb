# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
from sklearn.linear_model import Ridge

# %%
x,y = make_regression(n_samples=1000, n_features=1, n_informative=1, n_targets=1,noise=40,random_state=13)

# %%
plt.scatter(x, y)

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 1.1234308860670927

# %%
model.coef_
# Out:
# array([89.2066279])

# %%
model_ridge = Ridge(alpha=10)

# %%
model_ridge.fit(x,y)
# Out:
# Ridge(alpha=10)

# %%
model_ridge.coef_
# Out:
# array([88.29593367])

# %%
model_ridge.intercept_
# Out:
# 1.1033909354205458

# %%
model_ridge2 = Ridge(alpha=30)
model_ridge2.fit(x,y)
# Out:
# 1.0645139781096773

# %%
model_ridge2.coef_
# Out:
# array([86.52921172])

# %%
model_ridge2.intercept_
# Out:
# 1.0645139781096773

# %%
model_ridge3 = Ridge(alpha=100)
model_ridge3.fit(x,y)
# Out:
# Ridge(alpha=100)

# %%
model_ridge3.coef_
# Out:
# array([80.86601573])

# %%
model_ridge3.intercept_
# Out:
# 0.9398945784661146

# %%
model_ridge4 = Ridge(alpha=5)
model_ridge4.fit(x,y)
# Out:
# Ridge(alpha=5)

# %%
model_ridge4.coef_
# Out:
# array([88.74894458])

# %%
model_ridge4.intercept_
# Out:
# 1.1133595022817269

# %%
plt.figure(figsize=(20,20))

plt.plot(x,y,'b.')

plt.plot(x,model_ridge.predict(x),color='red',label='alpha=0')

plt.plot(x,model_ridge2.predict(x),color='green',label='alpha=10')

plt.plot(x,model_ridge3.predict(x),color='orange',label='alpha=100')

plt.plot(x,model_ridge4.predict(x),color='yellow',label='alpha=5')
plt.legend()
plt.show()

# %%
class Ridge_test:
    
    def __init__(self,alpha=0.1):
        self.alpha = alpha
        self.m = None
        self.b = None
        
    def fit(self,x_train,y_train):
        
        num = 0
        den = 0
        
        for i in range(x_train.shape[0]):
            num = num + (y_train[i] - y_train.mean())*(x_train[i] - x_train.mean())
            den = den + (x_train[i] - x_train.mean())*(x_train[i] - x_train.mean())
        
        self.m = num/(den + self.alpha)
        self.b = y_train.mean() - (self.m*x_train.mean())
        print(self.m,self.b)

# %%
model5 = Ridge_test(alpha=100)

# %%
model5.fit(x,y )
# Out:
# [80.86601573] [0.93989458]
