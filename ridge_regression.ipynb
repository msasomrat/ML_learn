# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge


from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import load_diabetes


from sklearn.metrics import r2_score,mean_squared_error

# %%
from sklearn.pipeline import Pipeline

from sklearn.preprocessing import PolynomialFeatures

# %%
df = load_diabetes()

# %%
df
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
df.DESCR
# Out:
# '.. _diabetes_dataset:\n\nDiabetes dataset\n----------------\n\nTen baseline variables, age, sex, body mass index, average blood\npressure, and six blood serum measurements were obtained for each of n =\n442 diabetes patients, as well as the response of interest, a\nquantitative measure of disease progression one year after baseline.\n\n**Data Set Characteristics:**\n\n:Number of Instances: 442\n\n:Number of Attributes: First 10 columns are numeric predictive values\n\n:Target: Column 11 is a quantitative measure of disease progression one year after baseline\n\n:Attribute Information:\n    - age     age in years\n    - sex\n    - bmi     body mass index\n    - bp      average blood pressure\n    - s1      tc, total serum cholesterol\n    - s2      ldl, low-density lipoproteins\n    - s3      hdl, high-density lipoproteins\n    - s4      tch, total cholesterol / HDL\n    - s5      ltg, possibly log of serum triglycerides level\n    - s6      glu, blood sugar level\n\nNote: Each of th
# ...

# %%
x = df.data

# %%
y = df.target

# %%
x
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
x_train
# Out:
# array([[-0.08906294, -0.04464164, -0.01159501, ...,  0.03430886,
#          0.02268774, -0.00936191],
#        [-0.03457486, -0.04464164, -0.0374625 , ..., -0.00259226,
#         -0.03074792, -0.07149352],
#        [ 0.01628068,  0.05068012, -0.04500719, ..., -0.03949338,
#         -0.03074792,  0.03620126],
#        ...,
#        [ 0.01628068, -0.04464164,  0.02612841, ..., -0.03395821,
#         -0.05140387, -0.02593034],
#        [-0.09632802, -0.04464164, -0.06979687, ..., -0.03949338,
#         -0.04688253, -0.07977773],
#        [ 0.08166637,  0.05068012,  0.00672779, ...,  0.09187461,
#          0.05471997,  0.00720652]])

# %%
x_test
# Out:
# array([[ 3.08108295e-02, -4.46416365e-02,  4.01399650e-02,
#          7.69580011e-02,  1.76943802e-02,  3.78296803e-02,
#         -2.86742944e-02,  3.43088589e-02, -1.49594876e-03,
#          1.19043403e-01],
#        [ 1.10726675e-01,  5.06801187e-02, -3.31512560e-02,
#         -2.28846772e-02, -4.32086554e-03,  2.02933664e-02,
#         -6.18090347e-02,  7.12099798e-02,  1.55684593e-02,
#          4.44854786e-02],
#        [-5.27375548e-02, -4.46416365e-02, -6.22521820e-02,
#         -2.63275281e-02, -5.69681839e-03, -5.07165897e-03,
#          3.02319104e-02, -3.94933829e-02, -3.07479175e-02,
#         -7.14935151e-02],
#        [ 1.26481373e-02, -4.46416365e-02, -2.02175111e-02,
#         -1.59989752e-02,  1.21905688e-02,  2.12328118e-02,
#         -7.65355859e-02,  1.08111101e-01,  5.98794036e-02,
#         -2.17882321e-02],
#        [ 1.99132142e-02, -4.46416365e-02, -3.42290681e-02,
#          5.51647545e-02,  6.72286831e-02,  7.41549019e-02,
# ...

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
prediction = model.predict(x_test)

# %%
r2_score(y_test, prediction)
# Out:
# 0.5188113124539249

# %%
np.sqrt(mean_squared_error(y_test, prediction))
# Out:
# 48.72713760953252

# %%
model.coef_
# Out:
# array([  23.45465406, -247.42747406,  492.1087518 ,  329.35876431,
#        -970.79723039,  573.54295519,  182.42162368,  255.92168168,
#         794.21609282,   89.32249214])

# %%
model.intercept_
# Out:
# 152.13623331746496

# %%
model_ridge = Ridge(alpha=100000)

# %%
model_ridge.fit(x_train, y_train)
# Out:
# Ridge(alpha=100000)

# %%
prediction_ridge = model_ridge.predict(x_test)

# %%
r2_score(y_test, prediction_ridge)
# Out:
# -0.00042490200441935855

# %%
np.sqrt(mean_squared_error(y_test, prediction_ridge))
# Out:
# 70.25956272917782

# %%
model_ridge.coef_
# Out:
# array([ 0.00260126,  0.00057066,  0.00776597,  0.0060976 ,  0.00233864,
#         0.00184724, -0.00513942,  0.0052716 ,  0.00734598,  0.00528629])

# %%
model_ridge.intercept_
# Out:
# 151.83287930791352

# %%
m = 100
x1 = 5 * np.random.rand(m, 1) - 3
x2 = 0.7 * x1 ** 3 - 2 * x1 + 4 + np.random.randn(m, 1)

plt.scatter(x1, x2)
plt.show()

# %%
x_train,x_test,y_train,y_test=train_test_split(x1,x2,test_size=0.2,random_state=45)

# %%
model_linear = LinearRegression()

# %%
model_linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
plt.plot(x1,x2, 'b.')
plt.plot(x_test, model_linear.predict(x_test), color = 'r')

# %%
r2_score(y_test, model_linear.predict(x_test))
# Out:
# 0.3394272936401531

# %%
def get_preds_ridge(x1, x2, alpha):
    model = Pipeline([
        ('poly_feats', PolynomialFeatures(degree=20)),
        ('ridge', Ridge(alpha=alpha))
    ])
    model.fit(x1, x2)
    return model.predict(x1)

alphas = [0, 20, 200]
cs = ['r', 'g', 'b']

plt.figure(figsize=(10, 6))
plt.plot(x1, x2, 'b+', label='Datapoints')

for alpha, c in zip(alphas, cs):
    preds = get_preds_ridge(x1, x2, alpha)
    
    plt.plot(sorted(x1[:, 0]), preds[np.argsort(x1[:, 0])], c, label='Alpha: {}'.format(alpha))

plt.legend()
plt.show()
# Out:
# C:\Users\shoab\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=1.14087e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\Users\shoab\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_ridge.py:204: LinAlgWarning: Ill-conditioned matrix (rcond=6.39398e-18): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
