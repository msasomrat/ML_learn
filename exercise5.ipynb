# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
df = pd.read_csv('HR_comma_sep.csv')

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
# %matplotlib inline 
plt.scatter(df.time_spend_company, df.promotion_last_5years, marker='+', color='red')

# %%
# %matplotlib inline 
plt.scatter(df.average_montly_hours, df.left, marker='+', color='red')

# %%
# %matplotlib inline 
plt.scatter(df.satisfaction_level, df.left, marker='+', color='red')

# %%
# %matplotlib inline 
plt.scatter(df.number_project, df.left, marker='+', color='red')

# %%
# %matplotlib inline 
plt.scatter(df.Work_accident, df.left, marker='+', color='red')

# %%
left = df[df.left ==1]
left
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
left.shape
# Out:
# (3571, 10)

# %%
retained = df[df.left == 0]
retained.shape
# Out:
# (11428, 10)

# %%
df_final = df.drop(['Department', 'salary'], axis='columns')
df_final
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df_final.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
df_final[df.satisfaction_level< 0.44]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 2                    0.11             0.88               7
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 2                       272                   4              0     1
# ...

# %%
df_final_after_decision = df[(df['satisfaction_level']> 0.66) & (df['average_montly_hours'] < 207) & (df['promotion_last_5years']>0.0261)]
df_final_after_decision
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 82                   0.79             0.59               4
# 4499                 0.94             0.80               5
# 4502                 0.72             0.49               3
# 4503                 0.95             0.96               5
# 4505                 0.77             0.79               3
# ...                   ...              ...             ...
# 14103                0.78             0.62               4
# 14104                0.74             0.79               5
# 14150                0.92             0.70               3
# 14208                0.85             0.54               3
# 14293                0.79             0.59               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 82                      139                   3              0     1
# 4499                    111                   4              0     0
# ...

# %%
df_final_after_decision.to_csv('HR_After_decision.csv')

# %%
pd.crosstab(df.salary, df.left)
# Out:
# left       0     1
# salary
# high    1155    82
# low     5144  2172
# medium  5129  1317

# %%
pd.crosstab(df.salary, df.left).plot()
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.salary, df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df.Department, df.left).plot()
# Out:
# <Axes: xlabel='Department'>

# %%
pd.crosstab(df.Department, df.left).plot(kind='bar')
# Out:
# <Axes: xlabel='Department'>

# %%
sub_df = df[['satisfaction_level', 'average_montly_hours', 'promotion_last_5years','salary']]
sub_df
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                    0.38                   157                      0     low
# 1                    0.80                   262                      0  medium
# 2                    0.11                   272                      0  medium
# 3                    0.72                   223                      0     low
# 4                    0.37                   159                      0     low
# ...                   ...                   ...                    ...     ...
# 14994                0.40                   151                      0     low
# 14995                0.37                   160                      0     low
# 14996                0.37                   143                      0     low
# 14997                0.11                   280                      0     low
# 14998                0.37                   158                      0     low
#
# ...

# %%
dummies = pd.get_dummies(sub_df.salary, prefix='salary')
df_dummies = pd.concat([sub_df, dummies], axis='columns')
df_dummies
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary  salary_high  salary_low  salary_medium
# 0         low        False        True          False
# ...

# %%
df_dummies.drop('salary', axis='columns', inplace= True)

# %%
df_dummies
# Out:
#        satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                    0.38                   157                      0
# 1                    0.80                   262                      0
# 2                    0.11                   272                      0
# 3                    0.72                   223                      0
# 4                    0.37                   159                      0
# ...                   ...                   ...                    ...
# 14994                0.40                   151                      0
# 14995                0.37                   160                      0
# 14996                0.37                   143                      0
# 14997                0.11                   280                      0
# 14998                0.37                   158                      0
#
#        salary_high  salary_low  salary_medium
# 0            False        True          False
# ...

# %%
x= df_dummies

# %%
y = df.left

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 14994    1
# 14995    1
# 14996    1
# 14997    1
# 14998    1
# Name: left, Length: 14999, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y ,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression()

# %%
log_reg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
log_reg.predict(x_test)
# Out:
# array([0, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
log_reg.score(x_train, y_train )
# Out:
# 0.778481540128344

# %%
log_reg.score(x_test, y_test )
# Out:
# 0.777
