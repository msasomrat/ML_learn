# %%
import pandas as pd
import numpy as np

# %%
from dtreeviz.trees import *
import dtreeviz

# %%
from sklearn.datasets import *

# %%
from sklearn.tree import plot_tree

# %%
from IPython.display import Image, display_svg, SVG

# %%
dct = tree.DecisionTreeClassifier()

# %%
 
iris = load_iris()

# %%
x_train = iris.data
y_train = iris.target
dct.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
plot_tree(dct)
# Out:
# [Text(0.5, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.4230769230769231, 0.75, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.46153846153846156, 0.8333333333333333, 'True  '),
#  Text(0.5769230769230769, 0.75, 'x[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.5384615384615384, 0.8333333333333333, '  False'),
#  Text(0.3076923076923077, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(0.15384615384615385, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(0.07692307692307693, 0.25, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(0.23076923076923078, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.46153846153846156, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.38461538461538464, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
# ...

# %%
from dtreeviz import dtreeviz

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from dtreeviz import dtreeviz  
from dtreeviz import model


iris = datasets.load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
class_names = iris.target_names


x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
import numpy as np
x_train = np.array(x_train)



dct = DecisionTreeClassifier(max_depth=3, random_state=42)
dct.fit(x_train, y_train)

viz = model(
    dct,                     
    x_train,                   
    y_train,                    
    feature_names=feature_names,  
    class_names=class_names,     
    target_name="species"        
)


viz.view()

# %%
from dtreeviz import dtreeviz

# %%
from dtreeviz import model
viz = model(dct, 
               x_train,
               y_train,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz.view()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from dtreeviz import model


url = "https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data"


column_names = [
    "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", 
    "TAX", "PTRATIO", "B", "LSTAT", "MEDV"
]


boston = pd.read_csv(url, delim_whitespace=True, names=column_names)

# Features and target
X = boston.drop(columns="MEDV")  
y = boston["MEDV"]               


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


regr = DecisionTreeRegressor(max_depth=3)
regr.fit(X_train, y_train)


viz = model(
    regr,
    X_train,
    y_train,
    target_name='MEDV',            
    feature_names=X.columns
)

# Display the visualization
viz.view()
# Out:
# C:\Users\shoab\AppData\Local\Temp\ipykernel_13092\3263034583.py:16: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# c:\Users\shoab\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names

# %%
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from dtreeviz import model  


iris = datasets.load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names
class_names = ["setosa", "versicolor", "virginica"]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


dct = DecisionTreeClassifier(max_depth=3, random_state=42)
dct.fit(X_train, y_train)


viz = model(
    dct,                  
    X_train,               
    y_train,              
    feature_names=feature_names,  
    class_names=class_names,      
    target_name="species"        
)


viz.view()

# %%
iris = load_iris()


clas = tree.DecisionTreeClassifier()
X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)


viz = model(
    clas,                       
    X_train,                    
    y_train,                    
    feature_names=iris.feature_names,  
    class_names=["setosa", "versicolor", "virginica"]  
)


viz.view()

# %%
iris = load_iris()


clas = tree.DecisionTreeClassifier()
X_train = iris.data
y_train = iris.target
clas.fit(X_train, y_train)


viz = model(
    clas,                       
    X_train,                    
    y_train,                    
    feature_names=iris.feature_names,  
    class_names=["setosa", "versicolor", "virginica"],  
    target_name='target'        
)


viz.view()

# %%
iris = load_iris()


class_names = iris.target_names
class_counts = [list(iris.target).count(i) for i in range(len(class_names))]


plt.figure(figsize=(8, 6))
plt.pie(class_counts, labels=class_names, autopct='%1.1f%%', startangle=140)
plt.title('Class Distribution in the Iris Dataset')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler


url = "https://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
column_names = ["MPG", "Cylinders", "Displacement", "Horsepower", "Weight", "Acceleration", "Model Year", "Origin"]


df_cars = pd.read_csv(url, delim_whitespace=True, names=column_names, na_values="?", comment='\t')


df_cars.dropna(inplace=True)


X = df_cars[['Weight', 'Horsepower']]
y = df_cars['MPG']


X['Horsepower'] = pd.to_numeric(X['Horsepower'], errors='coerce')


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


dt = DecisionTreeRegressor(max_depth=3, criterion='squared_error')  # Use one valid criterion value
dt.fit(X_scaled, y)


x_min, x_max = X_scaled[:, 0].min() - 1, X_scaled[:, 0].max() + 1
y_min, y_max = X_scaled[:, 1].min() - 1, X_scaled[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, 0.01),
                     np.arange(y_min, y_max, 0.01))


Z = dt.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)


fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')


ax.scatter(X_scaled[:, 0], X_scaled[:, 1], y, c='r', marker='o', label='Data Points')


ax.plot_surface(xx, yy, Z, color='b', alpha=0.5)

ax.set_xlabel('Weight')
ax.set_ylabel('Horsepower')
ax.set_zlabel('MPG')
ax.set_title('Decision Tree Regressor - 3D Visualization')

plt.show()
# Out:
# C:\Users\shoab\AppData\Local\Temp\ipykernel_13092\3432609786.py:13: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
# C:\Users\shoab\AppData\Local\Temp\ipykernel_13092\3432609786.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
